# %%
from dotenv import load_dotenv
import os

print("perfect!!")
load_dotenv()

GOOGLE_API_KEY=os.getenv("GOOGLE_API_KEY")
os.environ["GOOGLE_API_KEY"]=GOOGLE_API_KEY
# Out:
# perfect!!

# %%
import google.generativeai as genai

# %%
genai.configure(api_key=GOOGLE_API_KEY)

# %%
model = genai.GenerativeModel('gemini-2.5-flash')

# %%
response = model.generate_content("Write a story about a magic backpack.")
print(response.text)
# Out:
# Pip wasn't an extraordinary girl. She was, in fact, quite ordinary. She had mousy brown hair that never quite behaved, a scattering of freckles, and a habit of always forgetting something crucial: her lunch, her homework, or even, once, her left shoe (she’d had to hop all the way to school).
#
# Her grandmother, a woman who smelled of lavender and old books, decided enough was enough. For Pip’s tenth birthday, she presented her with a rather plain, moss-green canvas backpack. It looked sturdy, if a little boring.
#
# “It’s a special kind of bag, Pip,” Grandma May said, winking. “It knows what you need, sometimes even before you do.”
#
# Pip shrugged, polite but skeptical. It was just a backpack.
#
# The next morning, the magic began. Pip was already late for school, scrambling to find her math textbook. Panic began to bubble. She rummaged through her new backpack, expecting the usual jumble of crayons and half-eaten snacks. Instead, her hand closed around something rectangular and familiar. She pulled it out. It was her math textbook, crisp and new, exactly where she’d sworn she’d already looked a dozen times.
#
# “Huh,” she muttered, strapping the backpack on.
#
# That afternoon, a sudden downpour caught Pip on her walk home. She groaned, anticipating a soggy journey. Reaching into the backpack for a tissue (always hopeful, rarely successful), her fingers brushed against smooth, cool fabric. She pulled out a bright yellow umbrella, dry and perfectly unfurled. It wasn't one she owned.
#
# Over the next few weeks, the backpack became Pip’s quiet, quirky companion. When she forgot her lunch, a perfectly packed sandwich and a shiny apple would materialize. When she needed a specific colored pencil for an art project, the exact shade would be waiting. Once, when she was struggling with a tricky word in a book, she absentmindedly reached in and pulled out a dictionary, already open to the correct page.
#
# The magic wasn't flashy. It didn't grant wishes or fly her to the moon. It simply provided. It anticipated. And Pip started to change. She wasn't late as often, not because she remembered everything, but because she knew the backpack had her back. She grew a little more confident, a little less flustered.
#
# One sunny Saturday, Pip and her friend, Leo, were exploring the old woods behind their houses. Leo, usually full of boisterous energy, suddenly looked pale. “I think I twisted my ankle,” he whimpered, trying to stand.
#
# Pip's heart hammered. They were deep in the woods, far from any path. She started to panic, but then, a familiar, quiet hum seemed to emanate from her backpack. Taking a deep breath, she reached in. She pulled out a small, first-aid kit, neatly stocked with bandages, antiseptic wipes, and a cooling gel. Next, a foldable map of the woods, clearly marked with their current location and the quickest route back. And finally, a small, fully charged walkie-talkie, which instantly crackled to life with her dad's voice: "Pip? Everything okay? Heard a bit of a commotion from the backyard."
#
# Pip, with the backpack’s help, calmly talked her dad through their location, directed him to them, and comforted Leo. By the time her dad arrived, Leo's ankle was bandaged, and he was even managing a weak smile.
#
# Later that evening, after Leo was safely home and Pip had relayed the incredible story to her wide-eyed parents (who, after years of her eccentric grandmother, just nodded knowingly), Pip sat on her bed, the moss-green backpack beside her.
#
# She traced the rough canvas with her finger. It wasn’t just about the things it provided anymore. It was about the way it had empowered her, given her the tools to be brave, resourceful, and kind.
#
# Pip still forgot things sometimes. But now, when she reached into her magic backpack, she didn't just find what she needed. She found a quiet reminder that even the most ordinary of girls, with a little help and a touch of magic, could be extraordinary. And sometimes, she even found a perfectly baked cookie, just because.
